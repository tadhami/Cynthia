# %%
from PIL import Image 
from io import BytesIO
import requests 

def get_pokemon_image(pokemon_name, is_shiny):
    if (is_shiny == True):
        url = 'https://img.pokemondb.net/sprites/home/shiny/2x/' + pokemon_name + '.jpg'
    else:
        url = 'https://img.pokemondb.net/sprites/home/normal/2x/' + pokemon_name + '.jpg'
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    
    # https://stackoverflow.com/questions/273946/how-do-i-resize-an-image-using-pil-and-maintain-its-aspect-ratio
    basewidth = 150
    wpercent = (basewidth/float(img.size[0]))
    hsize = int((float(img.size[1])*float(wpercent)))
    img = img.resize((basewidth,hsize), Image.ANTIALIAS)

    return img 
try:
    image = get_pokemon_image("pachirisu", is_shiny = True) 
except:
    image = "Sorry, I'm not sure"
image
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x116799AF0>
